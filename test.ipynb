# %%
import sif_parser
from matplotlib import pyplot as plt
import numpy as np

# %%
data, info = sif_parser.np_open('./B-Au-50nm-50power-1.sif')
bg, _ = sif_parser.np_open('./B-Au-50nm-50power-Bg.sif')
ref, _ = sif_parser.np_open('./B-Au-50nm-50power-Rf.sif')

# %%
for i in range(3000):
    plt.plot(np.linspace(450,750,1600),(data[i].flatten() - bg[i].flatten())/ref[i].flatten())
